# %% [markdown]
# # 24th feb:

# %% [markdown]
# # conditional statements:

# %%
# if statement:

i = 10
if(i>15):
    print("10 is less than 15")
print("I am Not in if")
# Out:
# I am Not in if

# %%
# if else statement :

i=20
if(i<15):
    print("i is less than 15")
    print("i'm in if block")
else:
    print("i is greater than 15")
    print("i'm not in else block")
print("i'm not in if and not in else Block")
# Out:
# i is greater than 15
# i'm not in else block
# i'm not in if and not in else Block

# %%
# if else using list :

def digitSum(n):
    dsum=0
    for ele in str(n):
        dsum+=int(ele)
    return dsum

List =[367,111,562,945,6726,873]
newlist=[digitSum(i) for i in List if i & 1]
print(newlist)
# Out:
# [16, 3, 18, 18]

# %%
# nested if statement:

i=10
if(i==10):
    print("i is smaller than 15")
if(i<12):
    print("i is smaller than 12 too")
else:
    print("i is greater than 15")
# Out:
# i is smaller than 15
# i is smaller than 12 too

# %%
# if eelif-else :

i=25
if(i==10):
    print("i is 10")
elif(i==15):
    print("i is 15")
elif(i==20):
    print("i is 20")
else:
    print("i is not present")
# Out:
# i is not present

# %%
# ternary statement:

i=10
if i <15: print("i is less than 15")
# Out:
# i is less than 15

# %%
i=10
print(True) if i<15 else print(False)
# Out:
# True

# %%
x=10
if x>5:
    print("x is greater than 5")
else:
    print("x is not greater than 5")
# Out:
# x is greater than 5

# %%
x=10
if x>15:
    print("x is greater than 15")
elif x>5:
    print("x is greater than 5 but not greater than 15")
else:
    print("x is 5 or less")
# Out:
# x is greater than 5 but not greater than 15

# %%
x=int(input("Enter number"))

if(x%2==0):
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter number 5
# Odd number

# %%
x=int(input("Enter number"))

if(x%2==0):
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter number 6
# Even number

# %%
Age=int(input("enter your age"))

if(Age >= 18):
    print('Eligible to vote')
else:
    print("Not eligible")
# Out:
# enter your age 6
# Not eligible

# %%
Age=int(input("enter your age"))

if(Age >= 18):
    print('Eligible to vote')
else:
    print("Not eligible")
# Out:
# enter your age 55
# Eligible to vote

# %%
Year = int(input("Enter year:"))
if(Year%4==0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 55
# Not a Leap Year

# %%
Year = int(input("Enter year:"))
if(Year%400==0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2001
# Not a Leap Year

# %%
Year = int(input("Enter year:"))
if(Year%100!=0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2001
# Leap Year

# %%
Year = int(input("Enter year:"))
if(Year%4==0 and Year % 100!=0) or (Year% 400==0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2001
# Not a Leap Year

# %%
x=int(input("Enter a number:"))

if(x>0):
    print("positive")
elif(x<0):
    print("negative")
else:
    print("Zero")
# Out:
# Enter a number: 5
# positive

# %%
a=int(input("Enter a number"))
b=int(input("enter a number"))
if(a>b):
    print("a is greater number")
else:
    print("b is greater number")
# Out:
# Enter a number 65
# enter a number 55
# a is greater number

# %%
x=int(input("enter a number"))
if(x%5==0):
    print("It is multiple of 5")
else:
    print("Not multiple of 5")
# Out:
# enter a number 5
# It is multiple of 5

# %%
x=input("enter a character:")
if x in 'aeiou':
    print("Vowel")
else:
    print("Constant")
# Out:
# enter a character: l
# Constant

# %%
Age=int(input("enter your age"))

if(Age >= 60):
    print('eligible for senior citizen discount')
else:
    print("Not eligible")
# Out:
# enter your age 65
# eligible for senior citizen discount

# %%
num=int(input("enter a digits"))

if(0<= abs(num)<10):
    print('single digit')
else:
    print("Not single digit")
# Out:
# enter a digits 78
# Not single digit

# %%
hour = int(input("Enter hour (24-hour format): ")) 
if hour < 12: 
 print("Good Morning") 
else: 
 print("Good Afternoon")
# Out:
# Enter hour (24-hour format):  22
# Good Afternoon

# %%
s = input("Enter a string: ") 
if not s: 
 print("String is empty") 
else: 
 print("String is not empty")
# Out:
# Enter a string:
# String is empty

# %%
import math 


num = int(input("Enter a number")) 
if math.isqrt(num)**2==num: 
 print("Perfect Square") 
else: 
 print("Not a perfect square")
# Out:
# Enter a number 1
# Perfect Square

# %%
num = int(input("Enter a number"))

if(1 <= num <= 100): 
 print("Within range") 
else: 
 print("Out of range")
# Out:
# Enter a number 85
# Within range

# %%
day = input("Enter a day")
if day in ["saturday","sunday"]: 
 print("Weekend") 
else: 
 print("Weekday")
# Out:
# Enter a day thursday
# Weekday

# %%
num = int(input("Enter a number"))

if(num % 3 == 0 and num % 7 == 0): 
 print("Divisible by 3 and 7") 
else: 
 print("Not divisible by both")
# Out:
# Enter a number 21
# Divisible by 3 and 7

# %%
a = int(input("Enter first number:")) 
b = int(input("Enter second number:")) 

if (a + b)>100: 
 print("Sum is greater than 100") 
    
else: 
 print("Sum is 100 or less")
# Out:
# Enter first number: 4
# Enter second number: 4
# Sum is 100 or less

# %%
a = int(input("Enter first number")) 
b = int(input("Enter second number")) 

if a<b: 
 print("Minimum",a) 
else: 
 print("Minimum",b)
# Out:
# Enter first number 4
# Enter second number 65
# Minimum 4

# %%
x = int(input("Enter a number: ")) 
if x % 2 == 0 and x % 3 != 0: 
 print("Divisible by 2 but not by 3") 
else: 
 print("Does not meet criteria")
# Out:
# Enter a number:  2
# Divisible by 2 but not by 3

# %%
char = input("Enter an alphabet") 
if char.isupper(): 
 print("Uppercase") 
else: 
 print("Lowercase")
# Out:
# Enter an alphabet vagdevi
# Lowercase

# %%
a = int(input("Enter first side:")) 
b = int(input("Enter second side:")) 
c = int(input("Enter third side:")) 
if a + b > c and a + c > b and b + c > a: 
 print("Valid Triangle") 
else:
    print("Invalid Triangle")
# Out:
# Enter first side: 4
# Enter second side: 65
# Enter third side: 25
# Invalid Triangle

# %%
a = int(input("Enter first side:")) 
b = int(input("Enter second side:")) 
c = int(input("Enter third side:")) 
if a >= b and a >= c: 
 print("Largest:", a) 
elif b >= a and b >= c: 
 print("Largest:", b) 
else: 
 print("Largest:",c)
# Out:
# Enter first side: 5
# Enter second side: 5
# Enter third side: 8
# Largest: 8

# %%
num = int(input("Enter a number")) 
if num > 1:
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            print("Not a prime number")
            break
        else:
            print("Prime number") 
else: 
 print("Not a prime number")
# Out:
# Enter a number 65
# Prime number
# Prime number
# Prime number
# Not a prime number

# %%
Age = int(input("Enter age")) 
passed_test = input("Did you pass the driving test? (yes/no): ").lower() 
if Age >= 18 and passed_test == "yes": 
 print("Eligible for a driving license") 
else: 
 print("Not eligible")
# Out:
# Enter age 22
# Did you pass the driving test? (yes/no):  yes
# Eligible for a driving license

# %%
a = int(input("Enter first side")) 
b = int(input("Enter second side")) 
c = int(input("Enter third side")) 
if a == b == c: 
 print("Equilateral Triangle") 
elif a == b or b == c or a == c: 
 print("Isosceles Triangle") 
else: 
 print("Scalene Triangle")
# Out:
# Enter first side 4
# Enter second side 8
# Enter third side 2
# Scalene Triangle

# %%
marks = int(input("Enter marks")) 
if marks >= 40: 
 print("Pass") 
else: 
 print("Fail")
# Out:
# Enter marks 54
# Pass

# %%
x=input("Enter a number:")
if(x==x[::-1]):
    print("palindrome")
else:
    print("Not palindrome")
# Out:
# Enter a number: dad
# palindrome

# %%
marks=int(input("Enter a number:"))
if marks>=90:
    print("the student is A")
elif marks>=80:
    print("the student is B")
elif marks>=70:
    print("the student is C")
elif marks>=60 or marks >=40:
    print("the student is D")
else:
    print("the student is E(Fail)")
# Out:
# Enter a number: 54
# the student is D

# %%
import calendar

day = int(input("enter a day (1-31):"))
month = int(input("enter a month (1-12):"))
year = int(input("enter a year:"))

if 1 <= month <= 12 and 1 <= day <= calendar.monthrange(year, month)[1]:
    print("Valid date")
else:
    print("Not a valid date")
# Out:
# enter a day (1-31): 26
# enter a month (1-12): 12
# enter a year: 2001
# Valid date

# %%
hour = int(input("enter hour (24-hour format):"))
if hour < 12:
    print("AM")
else:
    print("PM")
# Out:
# enter hour (24-hour format): 20
# PM

# %%
num=input("enter a number:")
power=len(number)
if sum(int(digit)**power for digit in num)==int(num):
    print("Armstrong Number")
else:
    print("not a Armstrong number")
# Out:
# enter a number: 12
# not a Armstrong number

# %%
a=int(input("enter first side:"))
b=int(input("enter second side:"))
c=int(input("enter third side:"))
d=int(input("enter first side:"))
if a==b==c==d:
    print(square)
elif a==c and b==d:
    print(rectangle)
else:
    print("other quadrilateral")
# Out:
# enter first side: 2
# enter second side: 4
# enter third side: 4
# enter first side: 2
# other quadrilateral

# %%
# claculator:

a=float(input("enter first number:"))
b=float(input("enter secound number:"))
op = input("enter operation(+,-,*,/):")
if op == "+":
    print("result:",a+b)
elif op =="-":
    print("result:",a-b)
elif op=="*":
    print("result:",a*b)
elif op=="/":
    print("result:",a/b)
else:
    print("Invalid operation")
# Out:
# enter first number: 23
# enter secound number: 444.44
# enter operation(+,-,*,/): +
# result: 467.44

# %%
balance = float(input("Enter account balance: ")) 
withdraw = float(input("Enter withdrawal amount: ")) 
if balance >= withdraw: 
 print("Withdrawal successful") 
else: 
 print("Insufficient funds")

# %%
temperature=float(input("enter temperature:"))
unit=input("enter unit(C/F):").upper()
if unit=="c":
    print("Fahrenheit:",(temperature * 9/5)+32)
elif unit == "F":
    print("Celsius:",(temperature-32)*5/9)
else:
    print("Invalid unit")
# Out:
# enter temperature: 72.2
# enter unit(C/F): F
# Celsius: 22.333333333333332

# %%
number=int(input("Enter a number"))
if 50<= number <=100:
    print("within range")
else:
    print("out of range")
# Out:
# Enter a number 49
# out of range

# %%
year=int(input("Enter a number:"))
if year%100==0:
    print("Century Year")
else:
    print("not a century year")
# Out:
# Enter a number: 2025
# not a century year

# %%
num=int(input("enter a number:"))
if num>0 and (num &(num-1))==0:
    print("power of 2")
else:
    print("Not a power of 2")
# Out:
# enter a number: 8
# power of 2

# %%
month = int(input("Enter month (1-12):"))   
year = int(input("Enter year:"))  
days=[31,28+(1 if (year%4==0 and year%100!=0) or (year%400==0)else 0),31,30,31,30,31,31,30,31,30,31]
print("Days:",days[month-1])
# Out:
# Enter month (1-12): 12
# Enter year: 2001
# Days: 31

# %%
import re
password=input("enter password:")
if len(password)>=8 and re.search(r"[A-Za-z]",password) and re.search(r"\d",password):
    print("valid password")
else:
    print("invalid password")
# Out:
# enter password: vagdevig
# invalid password

# %%
age = int(input("Enter age: "))
if age < 5:   
    print("Ticket Price: Free")   
elif age >= 60:   
    print("Ticket Price: ₹50")   
else:   
    print("Ticket Price: ₹100")
# Out:
# Enter age:  45
# Ticket Price: ₹100

# %%
a, b, c = sorted(map(int, input("Enter three numbers: ").split())) 
if a**2 + b**2 == c**2: 
 print("Pythagorean Triplet") 
else: 
 print("Not a Pythagorean Triplet")
# Out:
# Enter three numbers:  2 3 4
# Not a Pythagorean Triplet

# %%
def roman_to_int(s):
    roman = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}
    total = 0
    for i in range(len(s)):
        if i > 0 and roman[s[i]] > roman[s[i - 1]]:
            total += roman[s[i]] - 2 * roman[s[i - 1]]
        else:
            total += roman[s[i]]
            return total 
num = input("Enter Roman numeral: ").upper() 
print("Integer:", roman_to_int(num))
# Out:
# Enter Roman numeral:  V
# Integer: 5

# %%
month = int(input("Enter birth month (1-12): "))   
day = int(input("Enter birth day: "))   
 
zodiac = [("Capricorn", 20), ("Aquarius", 19), ("Pisces", 20), ("Aries", 20),   
          ("Taurus", 21), ("Gemini", 21), ("Cancer", 22), ("Leo", 22),   
          ("Virgo", 22), ("Libra", 23), ("Scorpio", 23), ("Sagittarius", 22), ("Capricorn", 31)]   
 
sign = zodiac[month - 1][0] if day <= zodiac[month - 1][1] else zodiac[month][0]   
print("Zodiac Sign:", sign)
# Out:
# Enter birth month (1-12):  12
# Enter birth day:  26
# Zodiac Sign: Capricorn

# %%
num = int(input("Enter a number")) 
sum_digits = sum(int(digit) for digit in str(num)) 
if num % sum_digits == 0: 
 print("Harshad Number") 
else: 
 print("Not a Harshad Number")
# Out:
# Enter a number 23
# Not a Harshad Number

# %%
import re 

email = input("Enter email:") 
if re.match(r"^[\w\.-]+@[\w\.-]+\.(com|org|net|edu)$", email):
    print("Valid Email") 
else:
    print("Invalid Email")
# Out:
# Enter email: vagdevi0826@gmail.com
# Valid Email

# %%
x1, y1 = map(int, input("Enter current position (x y): ").split()) 
x2, y2 = map(int, input("Enter new position (x y): ").split()) 
if (abs(x1 - x2), abs(y1 - y2)) in [(2, 1), (1, 2)]:
    print("Valid Knight Move") 
else:
    print("Invalid Move")
# Out:
# Enter current position (x y):  1 2
# Enter new position (x y):  2 1
# Invalid Move

# %%
income = int(input("Enter monthly income: ")) 
credit_score = int(input("Enter credit score: ")) 
employed = input("Are you employed? (yes/no): ").lower() 
if income >= 25000 and credit_score >= 700 and employed == "yes": 
 print("Loan Approved") 
else: 
 print("Loan Denied")
# Out:
# Enter monthly income:  275000
# Enter credit score:  120
# Are you employed? (yes/no):  yes
# Loan Denied

# %%
import random 
choices = ["rock", "paper", "scissors"]   
user = input("Enter rock, paper, or scissors: ").lower()   
computer = random.choice(choices)
print("Computer chose:", computer)   
if user == computer:   
    print("It's a tie!")   
elif((user == "rock" and computer == "scissors") or   
     (user == "scissors" and computer == "paper") or   
     (user == "paper" and computer == "rock")):
    print("You win!")   
else:
    print("You lose!")
# Out:
# Enter rock, paper, or scissors:  paper
# Computer chose: paper
# It's a tie!

# %%
def day_of_week(d, m, y):
    if m < 3:
        m += 12
        y -= 1
    k = y % 100
    j = y // 100
    day = (d + (13 * (m + 1)) // 5 + k + (k // 4) + (j // 4) - 2 * j) % 7
    days = ["Saturday", "Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
    return days[day]
day, month, year = map(int, input("Enter date (DD MM YYYY): ").split())
print("Day of the Week:", day_of_week(day, month, year))
# Out:
# Enter date (DD MM YYYY):  26 12 2001
# Day of the Week: Wednesday

# %%
# electricity bill:

units=int(input("enter electricity units consumed"))
if(units<=100):
    bill=units*5
elif(units<=300):
    bill=(100*5)+(units-100)*10
else:
    bill=(100*5)+(200*10)+((units-300)*15)
print("total Bill:",bill)
# Out:
# enter electricity units consumed 200
# total Bill: 1500

# %%
num = -15
if num > 0:
   print("positive")
elif num<0:
   print("negative")
else:
   print("zero")
# Out:
# negative

# %%
num = int(input("enter a number:"))
if num > 0:
   print("positive")
elif num<0:
   print("negative")
else:
   print("zero")
# Out:
# enter a number: 23
# positive

# %%
number=10
if number>0:
    print("number is positive")
# Out:
# number is positive

# %%
number =10
if number>0:
    print("number is positive")
    print("statement is inside the if block")
print("statement is outside the if block")
# Out:
# number is positive
# statement is inside the if block
# statement is outside the if block

# %%
score=75
if score>=90:
    print("Excellent")
elif 80<=score<90:
    print("Very good")
elif 70<=score<80:
    print("Good")
elif 60<=score<70:
    print("Fair")
else:
    print("Need Improvement")
# Out:
# Good

# %%
score=75
if score>=60:
    print("Passing grade")
    if score>=90:
        print("Excellent")
    elif 80<=score<90:
        print("Very good")
    elif 70<=score<80:
        print("Good")
    elif 60<=score<70:
        print("Fair")
else:
    print("Failing grade")
# Out:
# Passing grade
# Good

# %%
age=20
message ="teenager" if age>=13 and age<=19 else "Not a teenger"
print("message")
# Out:
# message

# %%
x=10
if x>5:
    print("x is greater than 5")
else:
    pass
# Out:
# x is greater than 5

# %%
x =5
assert x>0, "value of x should be greater than 0"
print("the value of x is:",x)
# Out:
# the value of x is: 5

# %%
def say_hello():
    print("Helloo from my_script!")
if __name__=="__main__":
    say_hello()
# Out:
# Helloo from my_script!

# %%
list1=[1,2,3]
list2=[1,2,3]
print(list1==list2)
print(list1 is list2)
# Out:
# True
# False
