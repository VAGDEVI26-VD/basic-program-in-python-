# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url=r"C:\Users\Lenovo\Documents\Notes\FEBRUAURY\titanic dataset.csv"
df=pd.read_csv(url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pip install ollama
# Out:
# Requirement already satisfied: ollama in c:\users\lenovo\anaconda3\lib\site-packages (0.4.7)
# Requirement already satisfied: httpx<0.29,>=0.27 in c:\users\lenovo\anaconda3\lib\site-packages (from ollama) (0.27.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from ollama) (2.10.6)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (4.2.0)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (1.0.2)
# Requirement already satisfied: idna in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (3.7)
# Requirement already satisfied: sniffio in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ollama
import pandas as pd

def generate_insights(df_summary):
    prompt=f"Analyze the dataset summary and provide insights:\n\n{df_summary}"
    response=ollama.chat(
        model="mistral",
        messages=[{"role":"user","content":prompt}]
    )
    return response['message']['content']

summary=df.describe().to_string()
insights = generate_insights(summary)
print("\n AI-GENERATED INSIGHTS: \n", insights)
# Out:
#  AI-GENERATED INSIGHTS:
#   Here is the analysis of the given dataset, which appears to be a subset of the Titanic dataset:
#
# 1. Total Number of Rows (PassengerId): 891 - The dataset contains information about 891 passengers.
#
# 2. Mean and Standard Deviation for Each Column:
#    - Survived: Mean = 0.383838, Std Dev = 0.486592 - This suggests that approximately 38% of the passengers survived while about half of them did not survive. The standard deviation indicates a moderate spread in survival rates among the passengers.
#    - Pclass: Mean = 2.308642, Std Dev = 0.836071 - First-class passengers had an average ticket class of 1, while third-class passengers had an average of 3. The standard deviation indicates that there is some variation in the ticket classes among the passengers.
#    - Age: Mean = 29.699118, Std Dev = 14.526497 - The age of the passengers varies widely, with an average age of almost 30 years. The standard deviation suggests that passengers' ages are spread out across a wide range.
#    - SibSp: Mean = 0.523008, Std Dev = 1.102743 - This suggests that on average, each passenger traveled with half a sibling or less (since the values are fractional). The standard deviation indicates that there is significant variation in the number of siblings and spouses traveling together.
#    - Parch: Mean = 0.381594, Std Dev = 0.806057 - Similar to SibSp, this suggests that on average, each passenger traveled with about one-third of a parent or less (since the values are fractional). The standard deviation indicates variation in the number of parents traveling together.
#    - Fare: Mean = 32.204208, Std Dev = 49.693429 - This suggests that the average fare was approximately $32 while there was a wide range in fares among passengers.
#
# 3. Minimum and Maximum Values for Each Column:
#    - PassengerId: min = 1, max = 891 - The IDs of the passengers range from 1 to 891.
#    - Survived: min = 0, max = 1 - Only two values are possible: 0 (did not survive) and 1 (survived).
#    - Pclass: min = 1, max = 3 - First-class passengers had a ticket class of 1, second-class passengers had a ticket class of 2, and third-class passengers had a ticket class of 3.
#    - Age: min = 0.420000, max = 80.000000 - The ages of the passengers range from very young (less than one year old) to over 80 years old.
#    - SibSp: min = 0.000000, max = 8.000000 - Some passengers traveled alone (SibSp = 0), while others traveled with up to eight siblings or spouses.
#    - Parch: min = 0.000000, max = 6.000000 - Similar to SibSp, some passengers traveled alone (Parch = 0), while others traveled with up to six parents or other adults.
#    - Fare: min = 0.000000, max = 512.329200 - The fares range from free travel (Fare = 0) to over $500.

# %%
import gradio as gr
def eda_analysis(file):
    df=pd.read_csv(file)
    summary=df.describe().to_string()
    insights=generate_insights(summary)
    return insights

demo=gr.Interface(fn=eda_analysis,inputs="file",outputs="text")
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
def eda_analysis(file):
    df=pd.read_csv(file)
    summary=df.describe().to_string()
    insights=generate_insights(summary)
    return insights

demo=gr.Interface(fn=eda_analysis,inputs="file",outputs="text")
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
