# %%
import pandas as pd
import os

# %%
movies=pd.read_csv(r"C:\Users\Lenovo\Documents\Notes\FEBRUAURY\27th - Project\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film','Genre','CriticRating','AudienceRating','BudgetRating','Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetRating',
#        'Year'],
#       dtype='object')

# %%
movies.head(1)
# Out:
#                     Film   Genre  CriticRating  AudienceRating  BudgetRating  \
# 0  (500) Days of Summer   Comedy            87              81             8
#
#    Year
# 0  2009

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetRating         Year
# count    559.000000      559.000000    559.000000   559.000000
# mean      47.309481       58.744186     50.236136  2009.152057
# std       26.413091       16.826887     48.731817     1.362632
# min        0.000000        0.000000      0.000000  2007.000000
# 25%       25.000000       47.000000     20.000000  2008.000000
# 50%       46.000000       58.000000     35.000000  2009.000000
# 75%       70.000000       72.000000     65.000000  2010.000000
# max       97.000000       96.000000    300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetRating    559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film=movies.Film.astype('category')

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetRating  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# ...

# %%
movies.Genre=movies.Genre.astype("category")

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetRating  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# ...

# %%
movies.Year=movies.Year.astype("category")

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetRating  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetRating    559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetRating
# count    559.000000      559.000000    559.000000
# mean      47.309481       58.744186     50.236136
# std       26.413091       16.826887     48.731817
# min        0.000000        0.000000      0.000000
# 25%       25.000000       47.000000     20.000000
# 50%       46.000000       58.000000     35.000000
# 75%       70.000000       72.000000     65.000000
# max       97.000000       96.000000    300.000000

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetRating
# count    559.000000      559.000000    559.000000
# mean      47.309481       58.744186     50.236136
# std       26.413091       16.826887     48.731817
# min        0.000000        0.000000      0.000000
# 25%       25.000000       47.000000     20.000000
# 50%       46.000000       58.000000     35.000000
# 75%       70.000000       72.000000     65.000000
# max       97.000000       96.000000    300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating')
plt.show()

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='kde') 
# bivariate analysis
plt.show()

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='hex')
plt.show(j)

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='reg')
plt.show(j)

# %%
m1=sns.distplot(movies.AudienceRating)  # univariate analysis
plt.show(m1)

# %%
m1=sns.displot(movies.AudienceRating)
plt.show(m1)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.AudienceRating, bins = 15)
plt.show()

# %%
n1 = plt.hist(movies.AudienceRating, bins=15)
plt.show()

# %%
sns.set_style("white")
n1=plt.hist(movies.AudienceRating,bins=20)
plt.show()

# %%
n1=plt.hist(movies.CriticRating,bins=20)
plt.show()

# %%
plt.hist(movies.BudgetRating)
plt.show()

# %%
plt.hist(movies[movies.Genre =='Drama'].BudgetRating)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetRating  Year
# 0             8  2009
# 1           105  2008
# 2            20  2009
# 3            18  2010
# 4            20  2009

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetRating, bins = 20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetRating, bins = 20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetRating, bins = 20)
plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetRating,\
          movies[movies.Genre == 'Drama'].BudgetRating, \
          movies[movies.Genre == 'Thriller'].BudgetRating, \
          movies[movies.Genre == 'Comedy'].BudgetRating],bins = 20, stacked = True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',\
                fit_reg=False)
plt.show()

# %%
vis1=sns.lmplot(data=movies,x='CriticRating',y="AudienceRating",\
                fit_reg = False, hue='Genre')
plt.show()

# %%
vis1=sns.lmplot(data=movies,x="CriticRating",y="AudienceRating",\
                fit_reg=False,hue="Genre", height=10,aspect=1)
plt.show()

# %%
k1 = sns.kdeplot(data=movies,x="CriticRating",y="AudienceRating")
plt.show()

# %%
k1 = sns.kdeplot(data=movies,x="CriticRating",y="AudienceRating",shade = True,shade_lowest=False,cmap='Reds')
plt.show()

# %%
k2 = sns.kdeplot(data=movies,x="CriticRating",y="AudienceRating",shade_lowest=False,cmap='Greens_r')
plt.show()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(data=movies,x="BudgetRating",y="AudienceRating",shade_lowest=False,cmap='Greens_r')
plt.show()

# %%
sns.set_style("dark")
k1=sns.kdeplot(data=movies,x="BudgetRating",y="AudienceRating")
plt.show()

# %%
k2=sns.kdeplot(data=movies,x="BudgetRating",y="CriticRating")
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(12,6))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
f,axes=plt.subplots(1,2,figsize=(12,6))
k1=sns.kdeplot(data=movies,x="BudgetRating",y="AudienceRating",ax=axes[0])
k2=sns.kdeplot(data=movies,x="BudgetRating",y="CriticRating",ax=axes[1])
plt.show()

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetRating', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetRating', ylabel='CriticRating'>], dtype=object)

# %%
w=sns.boxplot(data=movies,x="Genre",y="CriticRating",hue="Genre")
plt.show()

# %%
z=sns.violinplot(data=movies,x='Genre',y='CriticRating',hue="Genre")
plt.show()

# %%
w1=sns.boxplot(data=movies[movies.Genre == 'Drama'],x='Year',y='CriticRating',hue="Year")
plt.show()

# %%
z=sns.violinplot(data=movies[movies.Genre == 'Drama'],x='Year',y="CriticRating",hue="Year")
plt.show()

# %%
z = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating')
plt.show()

# %%
g=sns.FacetGrid(data=movies,row='Genre',col='Year',hue='Genre')
plt.show(g)

# %%
plt.scatter(data=movies,x="CriticRating",y="AudienceRating")
plt.show()

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)
plt.show()

# %%
g=sns.FacetGrid(movies,row="Genre",col="Year",hue="Genre")
g=g.map(plt.scatter,"CriticRating","AudienceRating")
plt.show()

# %%
g=sns.FacetGrid(movies,row="Genre",col="Year",hue="Genre")
g=g.map(plt.hist,"BudgetRating")

# %%
plt.show()

# %%
g=sns.FacetGrid(movies,row="Genre",col="Year",hue="Genre")
kws=dict(s=50,linewidth=0.5,edgecolor="black")
g=g.map(plt.scatter,"CriticRating","AudienceRating",**kws)
plt.show()

# %%
sns.set_style("darkgrid")
f,axes=plt.subplots(2,2,figsize=(15,15))
k1=sns.kdeplot(data=movies,x="BudgetRating",y="AudienceRating", ax=axes[0,0])
k2 = sns.kdeplot(data=movies,x="BudgetRating",y="CriticRating", ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating',hue="Year", ax=axes[1,0])

k4 = sns.kdeplot(data=movies,x="CriticRating",y="AudienceRating",shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(data=movies,x="CriticRating", y="AudienceRating",cmap='Reds',ax = axes[1,1])
plt.show()

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(data=movies,x="BudgetRating",y="AudienceRating", \
                 shade = True, shade_lowest=True,cmap = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(data=movies,x="BudgetRating",y="AudienceRating", \
                 cmap = 'cool',ax = axes[0,0])

k2 = sns.kdeplot(data=movies,x="BudgetRating",y="CriticRating",\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(data=movies,x="BudgetRating",y="CriticRating",\
                  cmap = 'cool', ax = axes[0,1])

z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year', y = 'CriticRating',hue="Year", ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(data=movies,x="CriticRating",y="AudienceRating", \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(data=movies,x="CriticRating", y="AudienceRating", \
                  cmap='gist_gray_r',ax = axes[1,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()
