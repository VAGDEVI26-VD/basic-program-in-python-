# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style="whitegrid")
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline

# %%
import os
for dirname,_,filenames in os.walk(r"C:\Users\Lenovo\Documents\Notes\FEBRUAURY\28th - Seaborn, Eda Practicle\Seaborn - SPORT\FIFA.csv"):
    for filename in filenames:
        print(os.path.join(dirname,filename))

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
fifa=pd.read_csv(r"C:\Users\Lenovo\Documents\Notes\FEBRUAURY\28th - Seaborn, Eda Practicle\Seaborn - SPORT\FIFA.csv",index_col=0)

# %%
fifa.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Special                   18207 non-null  int64
#  13  Preferred Foot            18159 non-null  object
# ...

# %%
fifa['Body Type'].value_counts()
# Out:
# Body Type
# Normal                 10595
# Lean                    6417
# Stocky                  1140
# Messi                      1
# C. Ronaldo                 1
# Neymar                     1
# Courtois                   1
# PLAYER_BODY_TYPE_25        1
# Shaqiri                    1
# Akinfenwa                  1
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
x=fifa['Age']
ax=sns.distplot(x,bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fifa['Age']
x = pd.Series(x, name="Age variable")
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fifa['Age']
ax = sns.distplot(x, bins=10, vertical = True)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
x=fifa['Age']
x=pd.Series(x,name='Age variable')
ax=sns.kdeplot(x)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
x=fifa['Age']
x = pd.Series(x, name="Age variable")
ax = sns.kdeplot(x, shade=True, color='r')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fifa['Age']
ax = sns.distplot(x, kde=False, rug=True, bins=10)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
x=fifa['Age']
ax=sns.distplot(x,hist=False,rug=True,bins=10)
plt.show()

# %%
fifa['Preferred Foot'].nunique()
# Out:
# 2

# %%
fifa['Preferred Foot'].value_counts()
# Out:
# Preferred Foot
# Right    13948
# Left      4211
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.countplot(x="Preferred Foot", data=fifa, color="c")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.countplot(x="Preferred Foot", hue="Real Face", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.countplot(y="Preferred Foot", data=fifa, color="c")
plt.show()

# %%
g = sns.catplot(x="Preferred Foot", kind="count", palette="ch:.25", data=fifa)
plt.show()

# %%
fifa['International Reputation'].nunique()
# Out:
# 5

# %%
fifa['International Reputation'].value_counts()
# Out:
# International Reputation
# 1.0    16532
# 2.0     1261
# 3.0      309
# 4.0       51
# 5.0        6
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x="International Reputation",y="Potential",
              data=fifa,hue='International Reputation')
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x="International Reputation",y="Potential",
              hue="International Reputation",data=fifa,jitter=0.01)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x="International Reputation",y="Potential",
              hue='Preferred Foot',data=fifa,jitter=0.2,
              palette="Set2",dodge=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="International Reputation", y="Potential", hue="Preferred Foot",
              data=fifa, palette="Set2", size=20, 
              marker="D",edgecolor="gray", alpha=.25)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=fifa["Potential"])
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x='International Reputation',y='Potential',data=fifa,hue='International Reputation')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="International Reputation", y="Potential",
            hue="Preferred Foot", data=fifa, palette="Set3")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot(x=fifa["Potential"])
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot(x="International Reputation", y="Potential",
               hue='International Reputation',
               data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot(x="International Reputation", y="Potential",
               hue="Preferred Foot", data=fifa, palette="muted")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot(x="International Reputation", y="Potential", 
               hue="Preferred Foot", data=fifa,
               split=True, palette="muted")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential",
              hue="Preferred Foot", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential",
              hue="Preferred Foot", data=fifa, dodge=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential", hue="Preferred Foot", 
              data=fifa, markers=["o", "x"], 
              linestyles=["--", "-"])

plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential",
            data=fifa,hue='International Reputation')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential",
            hue="Preferred Foot", data=fifa)
plt.show()

# %%
from numpy import median
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", 
            data=fifa,hue="International Reputation",estimator=median)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential",
            data=fifa, ci=68)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", 
            hue='International Reputation',data=fifa, ci="sd")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential",
            data=fifa, capsize=0.2)
plt.show()

# %%
g = sns.relplot(x="Overall", y="Potential", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(x="Height", y="Weight", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.lineplot(x="Stamina", y="Strength", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="Overall", y="Potential", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="Overall", y="Potential", data=fifa, 
                 color= "g", marker="+")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.regplot(x="International Reputation", y="Potential",
            data=fifa, x_jitter=.01)
plt.show()

# %%
g= sns.lmplot(x="Overall", y="Potential", data=fifa)
plt.show()

# %%
g= sns.lmplot(x="Overall", y="Potential", hue="Preferred Foot", data=fifa)
plt.show()

# %%
g= sns.lmplot(x="Overall", y="Potential", hue="Preferred Foot", 
              data=fifa, palette="Set1")
plt.show()

# %%
g= sns.lmplot(x="Overall", y="Potential", col="Preferred Foot", 
              data=fifa)
plt.show()

# %%
g= sns.FacetGrid(col="Preferred Foot", 
              data=fifa)
plt.show()

# %%
g = sns.FacetGrid(fifa, col="Preferred Foot")
g = g.map(plt.hist, "Potential")
plt.show()

# %%
g = sns.FacetGrid(fifa, col="Preferred Foot")
g = g.map(plt.hist, "Potential", bins=10, color="r")
plt.show()

# %%
g = sns.FacetGrid(fifa, col="Preferred Foot")
g = (g.map(plt.scatter, "Height", "Weight",
           edgecolor="w").add_legend())

plt.show()

# %%
g = sns.FacetGrid(fifa, col="Preferred Foot", height=5, aspect=1)
g = g.map(plt.hist, "Potential")
plt.show()

# %%
fifa_new = fifa[['Age', 'Potential', 'Strength', 'Stamina', 'Preferred Foot']]

# %%
g = sns.PairGrid(fifa_new)
g = g.map(plt.scatter)
plt.show()

# %%
g = sns.PairGrid(fifa_new)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

plt.show()

# %%
g = sns.PairGrid(fifa_new, hue="Preferred Foot")
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()
plt.show()

# %%
g = sns.PairGrid(fifa_new, hue="Preferred Foot")
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()
plt.show()

# %%
g = sns.PairGrid(fifa_new, vars=['Age', 'Stamina'])
g = g.map(plt.scatter)
plt.show()

# %%
g = sns.PairGrid(fifa_new)
g = g.map_upper(plt.scatter)
g = g.map_lower(sns.kdeplot, cmap="Blues_d")
g = g.map_diag(sns.kdeplot, lw=3, legend=False)
plt.show()

# %%
g = sns.JointGrid(x="Overall", y="Potential", data=fifa)
g = g.plot(sns.regplot, sns.distplot)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
g = sns.JointGrid(x="Overall", y="Potential", data=fifa)
g = g.plot_joint(plt.scatter, color=".5", edgecolor="white")
g = g.plot_marginals(sns.distplot, kde=False, color=".5")
plt.show()

# %%
g = sns.JointGrid(x="Overall", y="Potential", data=fifa, space=0)
g = g.plot_joint(sns.kdeplot, cmap="Blues_d")
g = g.plot_marginals(sns.kdeplot, shade=True)
plt.show()

# %%
g = sns.JointGrid(x="Overall", y="Potential", data=fifa, height=5, ratio=2)
g = g.plot_joint(sns.kdeplot, cmap="Reds_d")
g = g.plot_marginals(sns.kdeplot, color="r", shade=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="Overall", y="Potential", data=fifa)
plt.show()

# %%
sns.lmplot(x="Overall", y="Potential", col="Preferred Foot", 
           data=fifa, col_wrap=2, height=5, aspect=1)
plt.show()

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
sinplot()
plt.show()

# %%
sns.set()
sinplot()
plt.show()

# %%
sns.set_style('whitegrid')
sinplot()
plt.show()

# %%
sns.set_style("dark")
sinplot()
plt.show()

# %%
sns.set_style("white")
sinplot()
plt.show()

# %%
sns.set_style("ticks")
sinplot()
plt.show()
