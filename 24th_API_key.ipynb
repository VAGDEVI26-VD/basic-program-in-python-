# %%
#pip install -q -U google-generativeai
#pip install -U google-generative

# %%
print('hello')
# Out:
# hello

# %%
import os
os.environ['GEMINI_API_KEY']="AIzaSyAoAo6f3YY3SsR-GpgmtJyixMwDNTOBiQ4"

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyAoAo6f3YY3SsR-GpgmtJyixMwDNTOBiQ4")
model = genai.GenerativeModel("gemini-2.0-flash")
response = model.generate_content("Explain how AI works")
print(response.text)
# Out:
# Okay, let's break down how AI works, keeping it as clear and concise as possible.  The term "AI" is broad, so I'll start with a general overview and then dive into some key concepts and types.
#
# **In a Nutshell: AI's Core Idea**
#
# At its heart, AI is about creating machines that can perform tasks that typically require human intelligence.  This includes things like:
#
# *   **Learning:**  Improving performance over time based on data.
# *   **Reasoning:**  Solving problems and making decisions.
# *   **Problem Solving:** Figuring out how to reach a goal.
# *   **Perception:**  Understanding sensory input (like images, sound, or text).
# *   **Natural Language Processing:** Understanding and generating human language.
#
# **Key Components and Concepts**
#
# 1.  **Data:** AI thrives on data.  The more data it has, the better it can learn and perform.  This data can be anything from images and text to numbers and sensor readings.
#
# ...

# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyAoAo6f3YY3SsR-GpgmtJyixMwDNTOBiQ4")
model = genai.GenerativeModel("gemini-2.0-flash")
response = model.generate_content("Explain how genAi work?")
print(response.text)
# Out:
# Okay, let's break down how Generative AI (GenAI) works.  It's a fascinating field, and understanding the core concepts makes it much less of a black box.
#
# **Core Idea: Learning Patterns from Data**
#
# At its heart, GenAI learns patterns and relationships from vast amounts of existing data and then uses those patterns to generate *new*, similar data. Think of it like this: you show a GenAI model millions of photos of cats, and it learns what features are common to cats (fur, pointy ears, whiskers, etc.).  Then, when asked to generate a new cat image, it uses its learned knowledge to create something that *looks* like a cat, even though it's never seen that *specific* cat before.
#
# **Key Components & Concepts**
#
# 1.  **Neural Networks:**
#
#     *   **Foundation:**  The backbone of most GenAI models is a neural network.  Inspired by the structure of the human brain, neural networks consist of interconnected "neurons" organized in layers.
# ...

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text=text.replace('.','*')
    return Markdown(textwrap.indent(text,'>',predicate=lambda _: True))

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# ...
